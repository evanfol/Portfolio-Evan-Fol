# %%
import sys

sys.path.append("../src")

from main import run_pipeline

run_pipeline()
# Out:
# DimCity enregistrée.
#
# Valeurs manquantes :
# datetime           0
# temperature        0
# humidity           0
# wind_speed         0
# city               0
# extraction_date    0
# dtype: int64
#
# Doublons : 0
#
# Températures invalides : 0
# Table weather prête avec clé primaire.
# Insertion / mise à jour terminée.
#
# Pipeline terminé.
